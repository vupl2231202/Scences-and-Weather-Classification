# %% [markdown]
# ## Download Data

# %%
# !pip install tensorflow==2.8.0

# %%
# !pip install -U --no-cache-dir gdown --pre
# weather-dataset.zip
# !gdown --id 1DYI92Au6-HeaM2ANLDm1cfmVoiFUOn4F

# %%
# !unzip weather-dataset.zip

# %%
import os 
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# ## Weather Recognition

# %%
# list đường dẫn các file ảnh
WEATHER_DATA_PATH = 'dataset'
path_imgs = list(glob.glob(WEATHER_DATA_PATH+'/**/*.jpg'))

# %%
# split đường dẫn các file để lấy label cho ảnh và tao thành dataframe để  thống kê
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1], path_imgs))
file_path = pd.Series(path_imgs, name='File_Path').astype(str)
labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                            File_Path     Labels
# 0  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...       rime
# 1  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...    fogsmog
# 2  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...    rainbow
# 3  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...        dew
# 4  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...  sandstorm

# %%
# vẽ các ảnh tương ứng với label
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.File_Path[i]))
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
# Thống kê số lượng ảnh cho từng label 
counts = data.Labels.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.xticks(rotation=50);

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory=WEATHER_DATA_PATH,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6862 files belonging to 11 classes.
# Using 5490 files for training.
# 2022-12-28 13:23:16.508287: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.527440: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.527536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.527908: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-28 13:23:16.528357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.528427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.528470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.822046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.822146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.822198: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 13:23:16.822253: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45913 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory=WEATHER_DATA_PATH,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6862 files belonging to 11 classes.
# Using 1372 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightning', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  layers.Rescaling(scale=1./255),
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.1),
  layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1), fill_mode='nearest')
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_augmentation(np.expand_dims(images[0].numpy(),axis=0).astype("uint8"))[0])
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ## ResNet34

# %%
class BuildResNet34():
    def __init__(self):
        pass

    def identity_block(self, inputs, filters):
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        
        skip_connection = layers.add([inputs, x])     
        x = layers.Activation('relu')(skip_connection)
        
        return x
    
    
    def projection_block(self, inputs, filters, strides=2):
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', strides=strides, use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        
        shortcut = layers.Conv2D(filters=filters, kernel_size=(1,1), padding='same', 
                                 strides=strides, use_bias=False)(inputs)
        shortcut = layers.BatchNormalization()(shortcut)
        skip_connection = layers.add([shortcut, x])        
        x = layers.Activation('relu')(skip_connection)
        
        return x
    
    def build_model(self, classes, input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        
        # conv1
        x = layers.ZeroPadding2D(padding=((3, 3)))(inputs)
        x = layers.Conv2D(64, 7, strides=2, use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.ZeroPadding2D(padding=((1, 1)))(x)
        x = layers.MaxPooling2D(3, strides=2)(x)
        
        # conv2_X
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        
        # conv3_x
        x = self.projection_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        
        # conv4_x
        x = self.projection_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        
        # conv5_x
        x = self.projection_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        
        x = layers.GlobalAveragePooling2D()(x)
        outputs = layers.Dense(classes, activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=outputs)
        
        return model

# %%
build_resnet34 = BuildResNet34()
resnet34_model = build_resnet34.build_model(classes=11)

image_input = layers.Input(shape=(img_height,img_width,3))
x = data_augmentation(image_input)
x = resnet34_model(x)
weather_resnet34_model = Model(inputs=image_input, outputs=x)

weather_resnet34_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  model (Functional)          (None, 11)                21307339
#
# =================================================================
# Total params: 21,307,339
# Trainable params: 21,290,315
# Non-trainable params: 17,024
# _________________________________________________________________

# %%
num_epochs = 50

weather_resnet34_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
                      metrics=['accuracy'])


history = weather_resnet34_model.fit(train_ds,
                                epochs = num_epochs,
                                validation_data = val_ds)
# Out:
# Epoch 1/50
# 2022-12-28 13:23:20.267903: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-12-28 13:23:21.103481: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 172/172 [==============================] - 13s 57ms/step - loss: 1.8033 - accuracy: 0.4301 - val_loss: 4.5610 - val_accuracy: 0.1115
# Epoch 2/50
# 172/172 [==============================] - 9s 55ms/step - loss: 1.2204 - accuracy: 0.5811 - val_loss: 3.1314 - val_accuracy: 0.2536
# Epoch 3/50
# 172/172 [==============================] - 10s 55ms/step - loss: 1.1159 - accuracy: 0.6160 - val_loss: 1.7148 - val_accuracy: 0.4461
# Epoch 4/50
# 172/172 [==============================] - 10s 55ms/step - loss: 1.0455 - accuracy: 0.6415 - val_loss: 1.1654 - val_accuracy: 0.6173
# Epoch 5/50
# 172/172 [==============================] - 10s 55ms/step - loss: 1.0018 - accuracy: 0.6530 - val_loss: 1.1570 - val_accuracy: 0.6254
# Epoch 6/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.9463 - accuracy: 0.6767 - val_loss: 1.2260 - val_accuracy: 0.6028
# Epoch 7/50
# 172/172 [==============================] - 10s 55ms/step - loss: 0.9388 - accuracy: 0.6758 - val_loss: 1.1353 - val_accuracy: 0.6305
# Epoch 8/50
# 172/172 [==============================] - 10s 55ms/step - loss: 0.9117 - accuracy: 0.6851 - val_loss: 0.9936 - val_accuracy: 0.6633
# Epoch 9/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.8798 - accuracy: 0.6936 - val_loss: 1.0848 - val_accuracy: 0.6217
# Epoch 10/50
# 172/172 [==============================] - 10s 55ms/step - loss: 0.8664 - accuracy: 0.6969 - val_loss: 1.1240 - val_accuracy: 0.6363
# Epoch 11/50
# 172/172 [==============================] - 10s 55ms/step - loss: 0.8443 - accuracy: 0.6985 - val_loss: 0.9886 - val_accuracy: 0.6647
# Epoch 12/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.8289 - accuracy: 0.7149 - val_loss: 1.0000 - val_accuracy: 0.6560
# Epoch 13/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.8106 - accuracy: 0.7140 - val_loss: 1.0190 - val_accuracy: 0.6538
# Epoch 14/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.7985 - accuracy: 0.7213 - val_loss: 1.0026 - val_accuracy: 0.6458
# Epoch 15/50
# 172/172 [==============================] - 10s 55ms/step - loss: 0.7867 - accuracy: 0.7199 - val_loss: 0.9706 - val_accuracy: 0.6757
# Epoch 16/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.7797 - accuracy: 0.7251 - val_loss: 1.0973 - val_accuracy: 0.6348
# Epoch 17/50
# 172/172 [==============================] - 10s 59ms/step - loss: 0.7598 - accuracy: 0.7353 - val_loss: 1.0397 - val_accuracy: 0.6458
# Epoch 18/50
# 172/172 [==============================] - 10s 55ms/step - loss: 0.7492 - accuracy: 0.7297 - val_loss: 1.0528 - val_accuracy: 0.6531
# Epoch 19/50
# 172/172 [==============================] - 10s 55ms/step - loss: 0.7322 - accuracy: 0.7404 - val_loss: 0.9440 - val_accuracy: 0.6880
# Epoch 20/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.7055 - accuracy: 0.7506 - val_loss: 1.0071 - val_accuracy: 0.6611
# Epoch 21/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.7029 - accuracy: 0.7525 - val_loss: 1.1197 - val_accuracy: 0.6378
# Epoch 22/50
# 172/172 [==============================] - 10s 59ms/step - loss: 0.6880 - accuracy: 0.7541 - val_loss: 0.9455 - val_accuracy: 0.6895
# Epoch 23/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.6667 - accuracy: 0.7661 - val_loss: 0.9394 - val_accuracy: 0.6953
# Epoch 24/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.6774 - accuracy: 0.7617 - val_loss: 1.0346 - val_accuracy: 0.6538
# Epoch 25/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.6499 - accuracy: 0.7714 - val_loss: 0.9995 - val_accuracy: 0.6691
# Epoch 26/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.6466 - accuracy: 0.7692 - val_loss: 0.9451 - val_accuracy: 0.6902
# Epoch 27/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.6347 - accuracy: 0.7699 - val_loss: 0.9586 - val_accuracy: 0.7128
# Epoch 28/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.6135 - accuracy: 0.7821 - val_loss: 0.8763 - val_accuracy: 0.7121
# Epoch 29/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.6297 - accuracy: 0.7714 - val_loss: 0.8839 - val_accuracy: 0.7106
# Epoch 30/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.6047 - accuracy: 0.7831 - val_loss: 0.9293 - val_accuracy: 0.6990
# Epoch 31/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.5850 - accuracy: 0.7914 - val_loss: 1.0694 - val_accuracy: 0.6771
# Epoch 32/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.5958 - accuracy: 0.7880 - val_loss: 0.9068 - val_accuracy: 0.7099
# Epoch 33/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.5699 - accuracy: 0.7927 - val_loss: 0.9599 - val_accuracy: 0.6902
# Epoch 34/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.5666 - accuracy: 0.7929 - val_loss: 0.9789 - val_accuracy: 0.6793
# Epoch 35/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.5545 - accuracy: 0.8031 - val_loss: 1.0465 - val_accuracy: 0.6691
# Epoch 36/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.5371 - accuracy: 0.8148 - val_loss: 0.8650 - val_accuracy: 0.7289
# Epoch 37/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.5383 - accuracy: 0.8035 - val_loss: 0.9121 - val_accuracy: 0.7106
# Epoch 38/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.5275 - accuracy: 0.8146 - val_loss: 1.0243 - val_accuracy: 0.7048
# Epoch 39/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.5175 - accuracy: 0.8133 - val_loss: 0.8966 - val_accuracy: 0.7194
# Epoch 40/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.5106 - accuracy: 0.8191 - val_loss: 0.8763 - val_accuracy: 0.7143
# Epoch 41/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.5091 - accuracy: 0.8209 - val_loss: 0.8767 - val_accuracy: 0.7289
# Epoch 42/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.4970 - accuracy: 0.8251 - val_loss: 0.8896 - val_accuracy: 0.7208
# Epoch 43/50
# 172/172 [==============================] - 10s 56ms/step - loss: 0.4848 - accuracy: 0.8281 - val_loss: 0.8864 - val_accuracy: 0.7354
# Epoch 44/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.4835 - accuracy: 0.8260 - val_loss: 0.9532 - val_accuracy: 0.7099
# Epoch 45/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.4699 - accuracy: 0.8341 - val_loss: 0.8693 - val_accuracy: 0.7267
# Epoch 46/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.4644 - accuracy: 0.8291 - val_loss: 1.0058 - val_accuracy: 0.7114
# Epoch 47/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.4572 - accuracy: 0.8339 - val_loss: 0.9138 - val_accuracy: 0.7354
# Epoch 48/50
# 172/172 [==============================] - 10s 57ms/step - loss: 0.4424 - accuracy: 0.8413 - val_loss: 0.9207 - val_accuracy: 0.7150
# Epoch 49/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.4356 - accuracy: 0.8430 - val_loss: 0.9105 - val_accuracy: 0.7201
# Epoch 50/50
# 172/172 [==============================] - 10s 58ms/step - loss: 0.4297 - accuracy: 0.8412 - val_loss: 0.8988 - val_accuracy: 0.7398

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error weather_resnet34_model')
plt.legend()
plt.grid(True)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy weather_resnet34_model')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 45  0.464393  0.829144  1.005803      0.711370     45
# 46  0.457162  0.833880  0.913781      0.735423     46
# 47  0.442448  0.841348  0.920749      0.715015     47
# 48  0.435596  0.842987  0.910524      0.720117     48
# 49  0.429695  0.841166  0.898771      0.739796     49
