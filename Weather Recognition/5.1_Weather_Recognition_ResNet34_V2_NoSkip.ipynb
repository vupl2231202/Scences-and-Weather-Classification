# %% [markdown]
# ## Download Data

# %%
# !pip install tensorflow==2.8.0

# %%
# !pip install -U --no-cache-dir gdown --pre
# weather-dataset.zip
# !gdown --id 1DYI92Au6-HeaM2ANLDm1cfmVoiFUOn4F

# %%
# !unzip weather-dataset.zip

# %%
import os 
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# ## Weather Recognition

# %%
# list đường dẫn các file ảnh
WEATHER_DATA_PATH = 'dataset'
path_imgs = list(glob.glob(WEATHER_DATA_PATH+'/**/*.jpg'))

# %%
# split đường dẫn các file để lấy label cho ảnh và tao thành dataframe để  thống kê
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1], path_imgs))
file_path = pd.Series(path_imgs, name='File_Path').astype(str)
labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                            File_Path     Labels
# 0  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...  lightning
# 1  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...       snow
# 2  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...       hail
# 3  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...  lightning
# 4  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...    rainbow

# %%
# vẽ các ảnh tương ứng với label
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.File_Path[i]))
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
# Thống kê số lượng ảnh cho từng label 
counts = data.Labels.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.xticks(rotation=50);

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory=WEATHER_DATA_PATH,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6862 files belonging to 11 classes.
# Using 5490 files for training.
# 2022-12-28 14:45:21.158162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.175297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.175366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.175739: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-28 14:45:21.176164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.176231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.176272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.441173: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.441270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.441321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:45:21.441375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45974 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory=WEATHER_DATA_PATH,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6862 files belonging to 11 classes.
# Using 1372 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightning', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  layers.Rescaling(scale=1./255),
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.1),
  layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1), fill_mode='nearest')
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_augmentation(np.expand_dims(images[0].numpy(),axis=0).astype("uint8"))[0])
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ## ResNet34_V2 No Skip Connection

# %%
class BuildResNet34_v2_NoSkip():
    def __init__(self):
        pass
    
    
    def identity_block(self, inputs, filters):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        
        return x
        
    
    def projection_block(self, inputs, filters):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', strides=2, use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        return x
    

    def build_model(self, classes, input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        x = layers.ZeroPadding2D(padding=(3,3))(inputs)
        x = layers.Conv2D(filters=64, kernel_size=(7,7), strides=2, use_bias=False)(x)
        x = layers.ZeroPadding2D(padding=(1,1))(x)
        x = layers.MaxPooling2D(pool_size=(3,3), strides=2)(x)
        
        # conv2_X
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        
        # conv3_x
        x = self.projection_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        
        # conv4_x
        x = self.projection_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        
        # conv5_x
        x = self.projection_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.GlobalAveragePooling2D()(x)
        x = layers.Dense(classes, activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=x)
        
        return model

# %%
build_resnet34_v2 = BuildResNet34_v2_NoSkip()
resnet34_v2_model_noskip = build_resnet34_v2.build_model(classes=11)

image_input = layers.Input(shape=(img_height,img_width,3))
x = data_augmentation(image_input)
x = resnet34_v2_model_noskip(x)
weather_resnet34_v2_model_noskip = Model(inputs=image_input, outputs=x)

weather_resnet34_v2_model_noskip.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  model (Functional)          (None, 11)                21131723
#
# =================================================================
# Total params: 21,131,723
# Trainable params: 21,116,491
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
num_epochs = 50

weather_resnet34_v2_model_noskip.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
                      metrics=['accuracy'])


history = weather_resnet34_v2_model_noskip.fit(train_ds,
                                epochs = num_epochs,
                                validation_data = val_ds)
# Out:
# Epoch 1/50
# 2022-12-28 14:45:24.789929: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-12-28 14:45:25.637000: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 172/172 [==============================] - 12s 53ms/step - loss: 2.2032 - accuracy: 0.2162 - val_loss: 4.3129 - val_accuracy: 0.1115
# Epoch 2/50
# 172/172 [==============================] - 9s 51ms/step - loss: 2.0111 - accuracy: 0.2772 - val_loss: 7.2620 - val_accuracy: 0.1115
# Epoch 3/50
# 172/172 [==============================] - 9s 51ms/step - loss: 1.8899 - accuracy: 0.3240 - val_loss: 2.5644 - val_accuracy: 0.2136
# Epoch 4/50
# 172/172 [==============================] - 9s 51ms/step - loss: 1.7131 - accuracy: 0.4002 - val_loss: 1.8524 - val_accuracy: 0.3586
# Epoch 5/50
# 172/172 [==============================] - 9s 50ms/step - loss: 1.5717 - accuracy: 0.4621 - val_loss: 1.8541 - val_accuracy: 0.3950
# Epoch 6/50
# 172/172 [==============================] - 9s 51ms/step - loss: 1.4686 - accuracy: 0.4923 - val_loss: 1.6842 - val_accuracy: 0.4534
# Epoch 7/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.3897 - accuracy: 0.5166 - val_loss: 1.5619 - val_accuracy: 0.4781
# Epoch 8/50
# 172/172 [==============================] - 9s 51ms/step - loss: 1.3390 - accuracy: 0.5355 - val_loss: 1.4662 - val_accuracy: 0.5131
# Epoch 9/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.2880 - accuracy: 0.5488 - val_loss: 1.3908 - val_accuracy: 0.5386
# Epoch 10/50
# 172/172 [==============================] - 9s 51ms/step - loss: 1.2592 - accuracy: 0.5674 - val_loss: 1.4206 - val_accuracy: 0.5313
# Epoch 11/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.2446 - accuracy: 0.5678 - val_loss: 1.3584 - val_accuracy: 0.5488
# Epoch 12/50
# 172/172 [==============================] - 9s 53ms/step - loss: 1.2129 - accuracy: 0.5836 - val_loss: 1.6507 - val_accuracy: 0.5160
# Epoch 13/50
# 172/172 [==============================] - 9s 53ms/step - loss: 1.1811 - accuracy: 0.5916 - val_loss: 1.2668 - val_accuracy: 0.5787
# Epoch 14/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.1749 - accuracy: 0.5896 - val_loss: 1.2803 - val_accuracy: 0.5765
# Epoch 15/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.1456 - accuracy: 0.5974 - val_loss: 1.4110 - val_accuracy: 0.5277
# Epoch 16/50
# 172/172 [==============================] - 9s 51ms/step - loss: 1.1312 - accuracy: 0.6046 - val_loss: 1.3122 - val_accuracy: 0.5685
# Epoch 17/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.1124 - accuracy: 0.6024 - val_loss: 1.1725 - val_accuracy: 0.6013
# Epoch 18/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.1034 - accuracy: 0.6100 - val_loss: 1.2498 - val_accuracy: 0.5780
# Epoch 19/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.0744 - accuracy: 0.6251 - val_loss: 1.1747 - val_accuracy: 0.6013
# Epoch 20/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.0815 - accuracy: 0.6162 - val_loss: 1.2287 - val_accuracy: 0.5926
# Epoch 21/50
# 172/172 [==============================] - 9s 51ms/step - loss: 1.0541 - accuracy: 0.6359 - val_loss: 1.2900 - val_accuracy: 0.5860
# Epoch 22/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.0418 - accuracy: 0.6346 - val_loss: 1.2590 - val_accuracy: 0.6028
# Epoch 23/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.0404 - accuracy: 0.6388 - val_loss: 1.3644 - val_accuracy: 0.5875
# Epoch 24/50
# 172/172 [==============================] - 9s 53ms/step - loss: 1.0249 - accuracy: 0.6313 - val_loss: 1.1539 - val_accuracy: 0.6188
# Epoch 25/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.0168 - accuracy: 0.6450 - val_loss: 1.1374 - val_accuracy: 0.6152
# Epoch 26/50
# 172/172 [==============================] - 9s 52ms/step - loss: 1.0097 - accuracy: 0.6474 - val_loss: 1.2555 - val_accuracy: 0.5809
# Epoch 27/50
# 172/172 [==============================] - 9s 53ms/step - loss: 0.9794 - accuracy: 0.6563 - val_loss: 1.2456 - val_accuracy: 0.5955
# Epoch 28/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.9658 - accuracy: 0.6617 - val_loss: 1.1663 - val_accuracy: 0.6013
# Epoch 29/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.9872 - accuracy: 0.6579 - val_loss: 1.0841 - val_accuracy: 0.6297
# Epoch 30/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.9567 - accuracy: 0.6645 - val_loss: 1.0794 - val_accuracy: 0.6443
# Epoch 31/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.9440 - accuracy: 0.6709 - val_loss: 1.1423 - val_accuracy: 0.6173
# Epoch 32/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.9507 - accuracy: 0.6719 - val_loss: 1.0545 - val_accuracy: 0.6589
# Epoch 33/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.9282 - accuracy: 0.6727 - val_loss: 1.1102 - val_accuracy: 0.6239
# Epoch 34/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.9088 - accuracy: 0.6760 - val_loss: 1.0960 - val_accuracy: 0.6297
# Epoch 35/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.9193 - accuracy: 0.6776 - val_loss: 1.1970 - val_accuracy: 0.6363
# Epoch 36/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.9132 - accuracy: 0.6863 - val_loss: 1.1120 - val_accuracy: 0.6297
# Epoch 37/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.8972 - accuracy: 0.6911 - val_loss: 1.0736 - val_accuracy: 0.6574
# Epoch 38/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.8895 - accuracy: 0.6829 - val_loss: 1.0411 - val_accuracy: 0.6625
# Epoch 39/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.8856 - accuracy: 0.6918 - val_loss: 1.2161 - val_accuracy: 0.6050
# Epoch 40/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.8726 - accuracy: 0.7000 - val_loss: 1.2372 - val_accuracy: 0.6042
# Epoch 41/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.8709 - accuracy: 0.6942 - val_loss: 1.1698 - val_accuracy: 0.6013
# Epoch 42/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.8506 - accuracy: 0.6967 - val_loss: 1.1024 - val_accuracy: 0.6363
# Epoch 43/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.8595 - accuracy: 0.6951 - val_loss: 0.9925 - val_accuracy: 0.6589
# Epoch 44/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.8427 - accuracy: 0.6989 - val_loss: 1.0377 - val_accuracy: 0.6538
# Epoch 45/50
# 172/172 [==============================] - 9s 53ms/step - loss: 0.8238 - accuracy: 0.7107 - val_loss: 1.0239 - val_accuracy: 0.6450
# Epoch 46/50
# 172/172 [==============================] - 9s 51ms/step - loss: 0.8341 - accuracy: 0.7138 - val_loss: 1.0944 - val_accuracy: 0.6363
# Epoch 47/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.8233 - accuracy: 0.7129 - val_loss: 1.1037 - val_accuracy: 0.6261
# Epoch 48/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.8103 - accuracy: 0.7162 - val_loss: 1.2584 - val_accuracy: 0.6181
# Epoch 49/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.8093 - accuracy: 0.7146 - val_loss: 1.0178 - val_accuracy: 0.6596
# Epoch 50/50
# 172/172 [==============================] - 9s 52ms/step - loss: 0.8141 - accuracy: 0.7113 - val_loss: 1.0585 - val_accuracy: 0.6297

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error weather_resnet34_v2_model_noskip')
plt.legend()
plt.grid(True)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy weather_resnet34_v2_model_noskip')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 45  0.834089  0.713843  1.094357      0.636297     45
# 46  0.823276  0.712933  1.103693      0.626093     46
# 47  0.810258  0.716211  1.258410      0.618076     47
# 48  0.809292  0.714572  1.017802      0.659621     48
# 49  0.814081  0.711293  1.058485      0.629738     49
