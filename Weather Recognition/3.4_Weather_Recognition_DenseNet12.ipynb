# %% [markdown]
# ## Download Data

# %%
# !pip install tensorflow==2.8.0

# %%
# !pip install -U --no-cache-dir gdown --pre
# weather-dataset.zip
# !gdown --id 1DYI92Au6-HeaM2ANLDm1cfmVoiFUOn4F

# %%
# !unzip weather-dataset.zip

# %%
import os 
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# ## Weather Recognition

# %%
# list đường dẫn các file ảnh
WEATHER_DATA_PATH = 'dataset'
path_imgs = list(glob.glob(WEATHER_DATA_PATH+'/**/*.jpg'))

# %%
# split đường dẫn các file để lấy label cho ảnh và tao thành dataframe để  thống kê
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1], path_imgs))
file_path = pd.Series(path_imgs, name='File_Path').astype(str)
labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                            File_Path   Labels
# 0  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...      dew
# 1  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...    glaze
# 2  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...     rime
# 3  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...  fogsmog
# 4  /home/aivn48/Desktop/DEL/Week25/2022/weather-d...     rime

# %%
# vẽ các ảnh tương ứng với label
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.File_Path[i]))
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
# Thống kê số lượng ảnh cho từng label 
counts = data.Labels.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.xticks(rotation=50);

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory=WEATHER_DATA_PATH,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6862 files belonging to 11 classes.
# Using 5490 files for training.
# 2022-12-28 14:07:33.235371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.252482: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.252555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.252976: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-28 14:07:33.253387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.253450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.253490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.517707: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.517801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.517848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-28 14:07:33.517899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46042 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory=WEATHER_DATA_PATH,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6862 files belonging to 11 classes.
# Using 1372 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightning', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  layers.Rescaling(scale=1./255),
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.1),
  layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1), fill_mode='nearest')
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_augmentation(np.expand_dims(images[0].numpy(),axis=0).astype("uint8"))[0])
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ## DenseNet121

# %%
class BuildDensenet121():
    def __init__(self):
        pass
    
    
    def conv_block(self, inputs, k=32):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=4*k, kernel_size=(1,1), use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=k, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        skip_connection = layers.Concatenate(axis=-1)([inputs,x])
        
        return skip_connection
    
    
    def dense_block(self, x, nums_block, k=32):
        for i in range(nums_block):
            x = self.conv_block(x, 32)
        return x
        
    
    
    def trasition_layer(self, inputs, fraction=0.5):
        channels = inputs.shape[-1]
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=fraction*channels, kernel_size=(1,1), use_bias=False)(x)
        x = layers.AveragePooling2D(2, strides=2)(x)
        
        return x
    
    def build_model(self, classes, input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        
        x = layers.ZeroPadding2D(padding=((3, 3)))(inputs)
        x = layers.Conv2D(64, 7, strides=2, use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.ZeroPadding2D(padding=((1, 1)))(x)
        x = layers.MaxPooling2D(3, strides=2)(x)
        
        # 1-6
        x = self.dense_block(x, nums_block=6)
        x = self.trasition_layer(x)
        
        # 2-12
        x = self.dense_block(x, nums_block=12)
        x = self.trasition_layer(x)
        
        # 3-24
        x = self.dense_block(x, nums_block=24)
        x = self.trasition_layer(x)
        
        #4-16
        x = self.dense_block(x, nums_block=16)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.GlobalAveragePooling2D()(x)
        outputs = layers.Dense(classes, activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=outputs)
        
        return model

# %%
build_densenet121 = BuildDensenet121()
densenet121_model = build_densenet121.build_model(classes=11)

image_input = layers.Input(shape=(img_height,img_width,3))
x = data_augmentation(image_input)
x = densenet121_model(x)
weather_densenet121_model = Model(inputs=image_input, outputs=x)

weather_densenet121_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  model (Functional)          (None, 11)                7048779
#
# =================================================================
# Total params: 7,048,779
# Trainable params: 6,965,131
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
num_epochs = 50

densenet121_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
                      metrics=['accuracy'])


history = densenet121_model.fit(train_ds,
                                epochs = num_epochs,
                                validation_data = val_ds)
# Out:
# Epoch 1/50
# 2022-12-28 14:07:40.101133: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-12-28 14:07:41.371186: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 172/172 [==============================] - 29s 132ms/step - loss: 1.6990 - accuracy: 0.4603 - val_loss: 1.9118 - val_accuracy: 0.3550
# Epoch 2/50
# 172/172 [==============================] - 21s 121ms/step - loss: 1.2934 - accuracy: 0.5776 - val_loss: 1.2987 - val_accuracy: 0.5496
# Epoch 3/50
# 172/172 [==============================] - 21s 120ms/step - loss: 1.1635 - accuracy: 0.6131 - val_loss: 1.1573 - val_accuracy: 0.6079
# Epoch 4/50
# 172/172 [==============================] - 21s 120ms/step - loss: 1.0854 - accuracy: 0.6439 - val_loss: 1.0765 - val_accuracy: 0.6414
# Epoch 5/50
# 172/172 [==============================] - 21s 122ms/step - loss: 1.0325 - accuracy: 0.6596 - val_loss: 1.0361 - val_accuracy: 0.6582
# Epoch 6/50
# 172/172 [==============================] - 21s 124ms/step - loss: 0.9705 - accuracy: 0.6805 - val_loss: 0.9935 - val_accuracy: 0.6676
# Epoch 7/50
# 172/172 [==============================] - 21s 123ms/step - loss: 0.9353 - accuracy: 0.6965 - val_loss: 0.9599 - val_accuracy: 0.6975
# Epoch 8/50
# 172/172 [==============================] - 21s 121ms/step - loss: 0.8906 - accuracy: 0.7049 - val_loss: 0.9182 - val_accuracy: 0.6946
# Epoch 9/50
# 172/172 [==============================] - 21s 123ms/step - loss: 0.8467 - accuracy: 0.7279 - val_loss: 0.8923 - val_accuracy: 0.7136
# Epoch 10/50
# 172/172 [==============================] - 21s 120ms/step - loss: 0.8163 - accuracy: 0.7324 - val_loss: 0.8685 - val_accuracy: 0.7157
# Epoch 11/50
# 172/172 [==============================] - 21s 122ms/step - loss: 0.7771 - accuracy: 0.7486 - val_loss: 0.8376 - val_accuracy: 0.7208
# Epoch 12/50
# 172/172 [==============================] - 21s 121ms/step - loss: 0.7498 - accuracy: 0.7647 - val_loss: 0.8183 - val_accuracy: 0.7289
# Epoch 13/50
# 172/172 [==============================] - 21s 120ms/step - loss: 0.7140 - accuracy: 0.7678 - val_loss: 0.7927 - val_accuracy: 0.7398
# Epoch 14/50
# 172/172 [==============================] - 21s 123ms/step - loss: 0.6896 - accuracy: 0.7761 - val_loss: 0.7816 - val_accuracy: 0.7456
# Epoch 15/50
# 172/172 [==============================] - 22s 126ms/step - loss: 0.2915 - accuracy: 0.9117 - val_loss: 0.7192 - val_accuracy: 0.7755
# Epoch 35/50
# 172/172 [==============================] - 21s 124ms/step - loss: 0.2870 - accuracy: 0.9164 - val_loss: 0.7687 - val_accuracy: 0.7813
# Epoch 36/50
# 172/172 [==============================] - 22s 126ms/step - loss: 0.2788 - accuracy: 0.9197 - val_loss: 0.7532 - val_accuracy: 0.7668
# Epoch 37/50
# 172/172 [==============================] - 22s 125ms/step - loss: 0.2552 - accuracy: 0.9260 - val_loss: 0.6890 - val_accuracy: 0.7959
# Epoch 38/50
# 172/172 [==============================] - 22s 125ms/step - loss: 0.2494 - accuracy: 0.9295 - val_loss: 0.8300 - val_accuracy: 0.7711
# Epoch 39/50
# 172/172 [==============================] - 22s 125ms/step - loss: 0.2304 - accuracy: 0.9346 - val_loss: 0.7364 - val_accuracy: 0.7813
# Epoch 40/50
# 172/172 [==============================] - 22s 126ms/step - loss: 0.2187 - accuracy: 0.9392 - val_loss: 0.7138 - val_accuracy: 0.7937
# Epoch 41/50
# 172/172 [==============================] - 21s 124ms/step - loss: 0.2074 - accuracy: 0.9428 - val_loss: 0.7053 - val_accuracy: 0.7996
# Epoch 42/50
# 172/172 [==============================] - 22s 125ms/step - loss: 0.2005 - accuracy: 0.9437 - val_loss: 0.6937 - val_accuracy: 0.8003
# Epoch 43/50
# 172/172 [==============================] - 22s 126ms/step - loss: 0.1990 - accuracy: 0.9475 - val_loss: 0.6826 - val_accuracy: 0.8039
# Epoch 44/50
# 172/172 [==============================] - 21s 124ms/step - loss: 0.1925 - accuracy: 0.9470 - val_loss: 0.8404 - val_accuracy: 0.7624
# Epoch 45/50
# 172/172 [==============================] - 22s 125ms/step - loss: 0.1696 - accuracy: 0.9550 - val_loss: 0.7089 - val_accuracy: 0.7923
# Epoch 46/50
# 172/172 [==============================] - 22s 126ms/step - loss: 0.1752 - accuracy: 0.9517 - val_loss: 0.8532 - val_accuracy: 0.7646
# Epoch 47/50
# 172/172 [==============================] - 21s 123ms/step - loss: 0.1582 - accuracy: 0.9585 - val_loss: 0.6998 - val_accuracy: 0.7974
# Epoch 48/50
# 172/172 [==============================] - 21s 124ms/step - loss: 0.1528 - accuracy: 0.9599 - val_loss: 0.7395 - val_accuracy: 0.7843
# Epoch 49/50
# 172/172 [==============================] - 21s 121ms/step - loss: 0.1534 - accuracy: 0.9587 - val_loss: 0.7867 - val_accuracy: 0.7864
# Epoch 50/50
# 172/172 [==============================] - 21s 122ms/step - loss: 0.1554 - accuracy: 0.9610 - val_loss: 0.7971 - val_accuracy: 0.7835

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error densenet121_model')
plt.legend()
plt.grid(True)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy densenet121_model')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 45  0.175185  0.951730  0.853178      0.764577     45
# 46  0.158233  0.958470  0.699831      0.797376     46
# 47  0.152842  0.959927  0.739511      0.784257     47
# 48  0.153408  0.958652  0.786692      0.786443     48
# 49  0.155395  0.961020  0.797103      0.783528     49
