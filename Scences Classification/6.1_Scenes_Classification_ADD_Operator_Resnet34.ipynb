# %% [markdown]
# ## Download Data

# %%
# !pip install tensorflow==2.8.0

# %%
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1hIA30U0onXAHyqeic-uuzJ-xbzt8J1EQ

# %%
# !unzip scenes_classification.zip

# %%
import os 
import cv2
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# ## Scenes Classification ADD Operator

# %%
# list đường dẫn các file ảnh
SCENES_CLASSIFICATION_PATH = 'scenes_classification'
train_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/train/**/*.jpg'))
val_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/val/**/*.jpg'))

# %%
# split đường dẫn các file để lấy label cho ảnh và tao thành dataframe để  thống kê
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1], train_path_imgs))
file_path = pd.Series(train_path_imgs, name='File_Path').astype(str)
labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                            File_Path     Labels
# 0  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...     street
# 1  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...     street
# 2  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...  buildings
# 3  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...     street
# 4  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...     street

# %%
# vẽ các ảnh tương ứng với label
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.File_Path[i]))
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
data.Labels.value_counts()
# Out:
# mountain     2512
# glacier      2404
# street       2382
# sea          2274
# forest       2271
# buildings    2191
# Name: Labels, dtype: int64

# %%
# Thống kê số lượng ảnh cho từng label 
counts = data.Labels.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.xticks(rotation=50);

# %%
batch_size = 32
img_height = 112
img_width = 112

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory= os.path.join(SCENES_CLASSIFICATION_PATH, 'train'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 14034 files belonging to 6 classes.
# 2022-12-29 13:52:34.461900: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-29 13:52:34.462322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:52:34.462420: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:52:34.462464: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:52:34.720066: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:52:34.720162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:52:34.720215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:52:34.720270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 40387 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory=os.path.join(SCENES_CLASSIFICATION_PATH, 'val'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3000 files belonging to 6 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
    layers.Rescaling(scale=1./255),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)
                                        , fill_mode='nearest'),
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_augmentation(np.expand_dims(images[0].numpy(),axis=0).astype("uint8"))[0])
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ## ResNet34 (skip connection: Add)

# %%
class BuildResNet34():
    def __init__(self):
        pass

    def identity_block(self, inputs, filters):
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        
        skip_connection = layers.add([inputs, x])     
        x = layers.Activation('relu')(skip_connection)
        
        return x
    
    
    def projection_block(self, inputs, filters, strides=2):
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', strides=strides, use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        
        shortcut = layers.Conv2D(filters=filters, kernel_size=(1,1), padding='same', 
                                 strides=strides, use_bias=False)(inputs)
        shortcut = layers.BatchNormalization()(shortcut)
        skip_connection = layers.add([shortcut, x])        
        x = layers.Activation('relu')(skip_connection)
        
        return x
    
    def build_model(self, classes, input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        
        # conv1
        x = layers.ZeroPadding2D(padding=((3, 3)))(inputs)
        x = layers.Conv2D(64, 7, strides=2, use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.ZeroPadding2D(padding=((1, 1)))(x)
        x = layers.MaxPooling2D(3, strides=2)(x)
        
        # conv2_X
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        
        # conv3_x
        x = self.projection_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        
        # conv4_x
        x = self.projection_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        
        # conv5_x
        x = self.projection_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        
        x = layers.GlobalAveragePooling2D()(x)
        outputs = layers.Dense(classes, activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=outputs)
        
        return model

# %%
build_resnet34 = BuildResNet34()
resnet34_model_add = build_resnet34.build_model(input_shape=(img_height, img_width, 3), classes=6)

image_input = layers.Input(shape=(img_height,img_width,3))
x = data_augmentation(image_input)
x = resnet34_model_add(x)
scenes_classification_resnet34_model_add = Model(inputs=image_input, outputs=x)

scenes_classification_resnet34_model_add.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  sequential (Sequential)     (None, 112, 112, 3)       0
#
#  model (Functional)          (None, 6)                 21304774
#
# =================================================================
# Total params: 21,304,774
# Trainable params: 21,287,750
# Non-trainable params: 17,024
# _________________________________________________________________

# %%
num_epochs = 100

scenes_classification_resnet34_model_add.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
                      metrics=['accuracy'])


history = scenes_classification_resnet34_model_add.fit(train_ds,
                                epochs = num_epochs,
                                validation_data = val_ds)
# Out:
# Epoch 1/100
# 2022-12-29 13:52:37.768651: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
#   1/439 [..............................] - ETA: 20:21 - loss: 2.3707 - accuracy: 0.0938
# 2022-12-29 13:52:38.577232: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 439/439 [==============================] - 18s 35ms/step - loss: 1.1847 - accuracy: 0.5390 - val_loss: 1.4262 - val_accuracy: 0.4773
# Epoch 2/100
# 439/439 [==============================] - 14s 33ms/step - loss: 0.9968 - accuracy: 0.6197 - val_loss: 0.9443 - val_accuracy: 0.6533
# Epoch 3/100
# 439/439 [==============================] - 14s 31ms/step - loss: 0.9033 - accuracy: 0.6612 - val_loss: 1.4293 - val_accuracy: 0.5087
# Epoch 4/100
# 439/439 [==============================] - 9s 22ms/step - loss: 0.8374 - accuracy: 0.6851 - val_loss: 1.7106 - val_accuracy: 0.4887
# Epoch 5/100
# 439/439 [==============================] - 10s 23ms/step - loss: 0.7820 - accuracy: 0.7119 - val_loss: 0.9806 - val_accuracy: 0.6447
# Epoch 6/100
# 439/439 [==============================] - 17s 38ms/step - loss: 0.7455 - accuracy: 0.7287 - val_loss: 1.5461 - val_accuracy: 0.5103
# Epoch 7/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.7166 - accuracy: 0.7361 - val_loss: 2.2079 - val_accuracy: 0.4107
# Epoch 8/100
# 439/439 [==============================] - 14s 32ms/step - loss: 0.6935 - accuracy: 0.7465 - val_loss: 1.3795 - val_accuracy: 0.5243
# Epoch 9/100
# 439/439 [==============================] - 13s 30ms/step - loss: 0.6687 - accuracy: 0.7613 - val_loss: 1.3274 - val_accuracy: 0.5720
# Epoch 10/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.6544 - accuracy: 0.7601 - val_loss: 1.2948 - val_accuracy: 0.5477
# Epoch 11/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.6408 - accuracy: 0.7686 - val_loss: 1.0595 - val_accuracy: 0.6437
# Epoch 12/100
# 439/439 [==============================] - 20s 47ms/step - loss: 0.6143 - accuracy: 0.7775 - val_loss: 1.5093 - val_accuracy: 0.5510
# Epoch 13/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.5974 - accuracy: 0.7858 - val_loss: 1.1583 - val_accuracy: 0.6157
# Epoch 14/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0
100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.2317 - accuracy: 0.9163 - val_loss: 0.8979 - val_accuracy: 0.7487
# Epoch 76/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2330 - accuracy: 0.9132 - val_loss: 0.5089 - val_accuracy: 0.8280
# Epoch 77/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.2302 - accuracy: 0.9168 - val_loss: 0.5739 - val_accuracy: 0.8093
# Epoch 78/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2208 - accuracy: 0.9184 - val_loss: 0.5949 - val_accuracy: 0.8087
# Epoch 79/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.2325 - accuracy: 0.9141 - val_loss: 1.1922 - val_accuracy: 0.7067
# Epoch 80/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2247 - accuracy: 0.9171 - val_loss: 0.7105 - val_accuracy: 0.7837
# Epoch 81/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2167 - accuracy: 0.9207 - val_loss: 0.7630 - val_accuracy: 0.7757
# Epoch 82/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.2206 - accuracy: 0.9176 - val_loss: 1.2801 - val_accuracy: 0.6940
# Epoch 83/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2196 - accuracy: 0.9213 - val_loss: 0.9135 - val_accuracy: 0.7507
# Epoch 84/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.2184 - accuracy: 0.9191 - val_loss: 0.6357 - val_accuracy: 0.8007
# Epoch 85/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.2146 - accuracy: 0.9201 - val_loss: 0.6727 - val_accuracy: 0.7947
# Epoch 86/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2116 - accuracy: 0.9223 - val_loss: 0.6643 - val_accuracy: 0.7963
# Epoch 87/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.2037 - accuracy: 0.9256 - val_loss: 0.6644 - val_accuracy: 0.7960
# Epoch 88/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2031 - accuracy: 0.9240 - val_loss: 0.8250 - val_accuracy: 0.7680
# Epoch 89/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.1977 - accuracy: 0.9275 - val_loss: 0.7899 - val_accuracy: 0.7773
# Epoch 90/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2031 - accuracy: 0.9238 - val_loss: 0.7316 - val_accuracy: 0.7947
# Epoch 91/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2004 - accuracy: 0.9249 - val_loss: 0.6725 - val_accuracy: 0.7930
# Epoch 92/100
# 439/439 [==============================] - 20s 47ms/step - loss: 0.1928 - accuracy: 0.9295 - val_loss: 0.7246 - val_accuracy: 0.7930
# Epoch 93/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2009 - accuracy: 0.9267 - val_loss: 0.6064 - val_accuracy: 0.8140
# Epoch 94/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.1910 - accuracy: 0.9266 - val_loss: 0.8114 - val_accuracy: 0.7770
# Epoch 95/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.1906 - accuracy: 0.9300 - val_loss: 0.5699 - val_accuracy: 0.8257
# Epoch 96/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.1857 - accuracy: 0.9324 - val_loss: 0.7838 - val_accuracy: 0.7857
# Epoch 97/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.1932 - accuracy: 0.9297 - val_loss: 1.1628 - val_accuracy: 0.7040
# Epoch 98/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.1892 - accuracy: 0.9303 - val_loss: 0.8814 - val_accuracy: 0.7550
# Epoch 99/100
# 439/439 [==============================] - 20s 47ms/step - loss: 0.1829 - accuracy: 0.9320 - val_loss: 0.8195 - val_accuracy: 0.7657
# Epoch 100/100
# 439/439 [==============================] - 20s 46ms/step - loss: 0.1773 - accuracy: 0.9343 - val_loss: 0.6074 - val_accuracy: 0.8247

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error scenes_classification_resnet34_model_add')
plt.legend()
plt.grid(True)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy scenes_classification_resnet34_model_add')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  0.185666  0.932450  0.783775      0.785667     95
# 96  0.193240  0.929742  1.162777      0.704000     96
# 97  0.189178  0.930312  0.881390      0.755000     97
# 98  0.182928  0.932022  0.819498      0.765667     98
# 99  0.177337  0.934302  0.607420      0.824667     99
