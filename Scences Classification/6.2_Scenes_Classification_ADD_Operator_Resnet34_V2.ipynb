# %% [markdown]
# ## Download Data

# %%
# !pip install tensorflow==2.8.0

# %%
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1hIA30U0onXAHyqeic-uuzJ-xbzt8J1EQ

# %%
# !unzip scenes_classification.zip

# %%
import os 
import cv2
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# ## Scenes Classification ADD Operator

# %%
# list đường dẫn các file ảnh
SCENES_CLASSIFICATION_PATH = 'scenes_classification'
train_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/train/**/*.jpg'))
val_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/val/**/*.jpg'))

# %%
# split đường dẫn các file để lấy label cho ảnh và tao thành dataframe để  thống kê
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1], train_path_imgs))
file_path = pd.Series(train_path_imgs, name='File_Path').astype(str)
labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                            File_Path   Labels
# 0  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...  glacier
# 1  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...   street
# 2  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...      sea
# 3  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...  glacier
# 4  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...  glacier

# %%
# vẽ các ảnh tương ứng với label
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.File_Path[i]))
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
data.Labels.value_counts()
# Out:
# mountain     2512
# glacier      2404
# street       2382
# sea          2274
# forest       2271
# buildings    2191
# Name: Labels, dtype: int64

# %%
# Thống kê số lượng ảnh cho từng label 
counts = data.Labels.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.xticks(rotation=50);

# %%
batch_size = 32
img_height = 112
img_width = 112

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory= os.path.join(SCENES_CLASSIFICATION_PATH, 'train'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 14034 files belonging to 6 classes.
# 2022-12-29 13:16:56.904692: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-29 13:16:56.905116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:16:56.905219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:16:56.905264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:16:57.440408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:16:57.440506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:16:57.440559: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 13:16:57.440612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 40449 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory=os.path.join(SCENES_CLASSIFICATION_PATH, 'val'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3000 files belonging to 6 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
    layers.Rescaling(scale=1./255),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)
                                        , fill_mode='nearest'),
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_augmentation(np.expand_dims(images[0].numpy(),axis=0).astype("uint8"))[0])
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ## ResNet34_V2 (skip connection: Add)

# %%
class BuildResNet34_v2():
    def __init__(self):
        pass
    
    
    def identity_block(self, inputs, filters):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        return layers.add([inputs, x])
            
        
    
    def projection_block(self, inputs, filters):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', strides=2, use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        
        shortcut = layers.BatchNormalization()(inputs)
        shortcut = layers.Activation('relu')(shortcut)
        shortcut = layers.Conv2D(filters=filters, kernel_size=(1,1), padding='same', 
                             strides=2, use_bias=False)(shortcut)
        return layers.add([shortcut,x])
    

    def build_model(self, classes, input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        x = layers.ZeroPadding2D(padding=(3,3))(inputs)
        x = layers.Conv2D(filters=64, kernel_size=(7,7), strides=2, use_bias=False)(x)
        x = layers.ZeroPadding2D(padding=(1,1))(x)
        x = layers.MaxPooling2D(pool_size=(3,3), strides=2)(x)
        
        # conv2_X
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        
        # conv3_x
        x = self.projection_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        
        # conv4_x
        x = self.projection_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        
        # conv5_x
        x = self.projection_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.GlobalAveragePooling2D()(x)
        outputs = layers.Dense(classes, activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=outputs)
        
        return model

# %%
build_resnet34_v2 = BuildResNet34_v2()
resnet34_v2_model_add = build_resnet34_v2.build_model(input_shape=(img_height, img_width, 3), classes=6)

image_input = layers.Input(shape=(img_height,img_width,3))
x = data_augmentation(image_input)
x = resnet34_v2_model_add(x)
scenes_classification_resnet34_v2_model_add = Model(inputs=image_input, outputs=x)

scenes_classification_resnet34_v2_model_add.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  sequential (Sequential)     (None, 112, 112, 3)       0
#
#  model (Functional)          (None, 6)                 21302982
#
# =================================================================
# Total params: 21,302,982
# Trainable params: 21,286,854
# Non-trainable params: 16,128
# _________________________________________________________________

# %%
num_epochs = 100

scenes_classification_resnet34_v2_model_add.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
                      metrics=['accuracy'])


history = scenes_classification_resnet34_v2_model_add.fit(train_ds,
                                epochs = num_epochs,
                                validation_data = val_ds)
# Out:
# Epoch 1/100
# 2022-12-29 13:17:01.410116: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-12-29 13:17:02.739299: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 439/439 [==============================] - 24s 45ms/step - loss: 1.1677 - accuracy: 0.5475 - val_loss: 1.2757 - val_accuracy: 0.5607
# Epoch 2/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.9674 - accuracy: 0.6337 - val_loss: 1.4943 - val_accuracy: 0.5123
# Epoch 3/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.8845 - accuracy: 0.6643 - val_loss: 1.2907 - val_accuracy: 0.5813
# Epoch 4/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.8383 - accuracy: 0.6899 - val_loss: 0.9077 - val_accuracy: 0.6687
# Epoch 5/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.7843 - accuracy: 0.7060 - val_loss: 1.1546 - val_accuracy: 0.6077
# Epoch 6/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.7636 - accuracy: 0.7170 - val_loss: 0.9068 - val_accuracy: 0.6743
# Epoch 7/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.7322 - accuracy: 0.7319 - val_loss: 1.1603 - val_accuracy: 0.6167
# Epoch 8/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.7016 - accuracy: 0.7458 - val_loss: 1.2910 - val_accuracy: 0.5533
# Epoch 9/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.6956 - accuracy: 0.7413 - val_loss: 1.3403 - val_accuracy: 0.5833
# Epoch 10/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.6652 - accuracy: 0.7573 - val_loss: 1.1675 - val_accuracy: 0.6177
# Epoch 11/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.6495 - accuracy: 0.7633 - val_loss: 0.8189 - val_accuracy: 0.6997
# Epoch 12/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.6366 - accuracy: 0.7703 - val_loss: 0.9080 - val_accuracy: 0.6870
# Epoch 13/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.6179 - accuracy: 0.7738 - val_loss: 1.2160 - val_accuracy: 0.6013
# Epoch 14/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.5970 - accuracy: 0.7836 - val_loss: 1.4510 - val_accuracy: 0.5520
# Epoch 15/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.5915 - accuracy: 0.7845 - val_loss: 1.0485 - val_accuracy: 0.6373
# Epoch 16/100
# 439/439 [==============================] - 19s 42ms/step - loss: 0.5840 - accuracy: 0.7892 - val_loss: 0.8189 - val_accuracy: 0.7127
# Epoch 17/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.5742 - accuracy: 0.7906 - val_loss: 1.3231 - val_accuracy: 0.6017
# Epoch 18/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0
100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2509 - accuracy: 0.9094 - val_loss: 0.8541 - val_accuracy: 0.7640
# Epoch 78/100
# 439/439 [==============================] - 19s 42ms/step - loss: 0.2552 - accuracy: 0.9059 - val_loss: 1.0694 - val_accuracy: 0.7067
# Epoch 79/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2536 - accuracy: 0.9082 - val_loss: 1.0017 - val_accuracy: 0.7310
# Epoch 80/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.2490 - accuracy: 0.9083 - val_loss: 0.7262 - val_accuracy: 0.7823
# Epoch 81/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2400 - accuracy: 0.9119 - val_loss: 1.0834 - val_accuracy: 0.7087
# Epoch 82/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2531 - accuracy: 0.9046 - val_loss: 0.9348 - val_accuracy: 0.7410
# Epoch 83/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2386 - accuracy: 0.9139 - val_loss: 0.5513 - val_accuracy: 0.8280
# Epoch 84/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2269 - accuracy: 0.9156 - val_loss: 0.9909 - val_accuracy: 0.7350
# Epoch 85/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.2291 - accuracy: 0.9143 - val_loss: 0.9915 - val_accuracy: 0.7240
# Epoch 86/100
# 439/439 [==============================] - 19s 44ms/step - loss: 0.2211 - accuracy: 0.9180 - val_loss: 0.5149 - val_accuracy: 0.8357
# Epoch 87/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2310 - accuracy: 0.9143 - val_loss: 1.2147 - val_accuracy: 0.6960
# Epoch 88/100
# 439/439 [==============================] - 19s 42ms/step - loss: 0.2220 - accuracy: 0.9181 - val_loss: 1.0764 - val_accuracy: 0.7257
# Epoch 89/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2246 - accuracy: 0.9193 - val_loss: 0.8944 - val_accuracy: 0.7627
# Epoch 90/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2249 - accuracy: 0.9178 - val_loss: 0.8615 - val_accuracy: 0.7593
# Epoch 91/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2138 - accuracy: 0.9212 - val_loss: 1.1481 - val_accuracy: 0.6947
# Epoch 92/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2188 - accuracy: 0.9206 - val_loss: 0.6916 - val_accuracy: 0.7910
# Epoch 93/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2131 - accuracy: 0.9192 - val_loss: 0.7137 - val_accuracy: 0.8017
# Epoch 94/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2166 - accuracy: 0.9180 - val_loss: 0.8197 - val_accuracy: 0.7757
# Epoch 95/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2125 - accuracy: 0.9237 - val_loss: 0.9123 - val_accuracy: 0.7437
# Epoch 96/100
# 439/439 [==============================] - 19s 43ms/step - loss: 0.2055 - accuracy: 0.9266 - val_loss: 0.5204 - val_accuracy: 0.8437
# Epoch 97/100
# 439/439 [==============================] - 18s 41ms/step - loss: 0.2112 - accuracy: 0.9210 - val_loss: 0.7877 - val_accuracy: 0.7770
# Epoch 98/100
# 439/439 [==============================] - 15s 33ms/step - loss: 0.1943 - accuracy: 0.9302 - val_loss: 1.1140 - val_accuracy: 0.7003
# Epoch 99/100
# 439/439 [==============================] - 15s 33ms/step - loss: 0.1999 - accuracy: 0.9246 - val_loss: 0.9713 - val_accuracy: 0.7613
# Epoch 100/100
# 439/439 [==============================] - 15s 34ms/step - loss: 0.1950 - accuracy: 0.9290 - val_loss: 0.7722 - val_accuracy: 0.7953

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error scenes_classification_resnet34_v2_model_add')
plt.legend()
plt.grid(True)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy scenes_classification_resnet34_v2_model_add')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  0.205461  0.926607  0.520419      0.843667     95
# 96  0.211172  0.920978  0.787688      0.777000     96
# 97  0.194287  0.930241  1.113985      0.700333     97
# 98  0.199939  0.924612  0.971300      0.761333     98
# 99  0.194996  0.929030  0.772236      0.795333     99
