# %% [markdown]
# ## Problem1: Skip Connection ResNet34

# %%
import os 
import cv2
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %%
class BuildResNet34():
    def __init__(self):
        pass

    def identity_block(self, inputs, filters):
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        
        skip_connection = layers.add([inputs, x])     
        x = layers.Activation('relu')(skip_connection)
        
        return x
    
    
    def projection_block(self, inputs, filters, strides=2):
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', strides=strides, use_bias=False)(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        
        x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        
        shortcut = layers.Conv2D(filters=filters, kernel_size=(1,1), padding='same', 
                                 strides=strides, use_bias=False)(inputs)
        shortcut = layers.BatchNormalization()(shortcut)
        skip_connection = layers.add([shortcut, x])        
        x = layers.Activation('relu')(skip_connection)
        
        return x
    
    def build_model(self, classes, input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        
        # conv1
        x = layers.ZeroPadding2D(padding=((3, 3)))(inputs)
        x = layers.Conv2D(64, 7, strides=2, use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.ZeroPadding2D(padding=((1, 1)))(x)
        x = layers.MaxPooling2D(3, strides=2)(x)
        
        # conv2_X
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        x = self.identity_block(x, filters=64)
        
        # conv3_x
        x = self.projection_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        x = self.identity_block(x, filters=128)
        
        # conv4_x
        x = self.projection_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        x = self.identity_block(x, filters=256)
        
        # conv5_x
        x = self.projection_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        x = self.identity_block(x, filters=512)
        
        x = layers.GlobalAveragePooling2D()(x)
        outputs = layers.Dense(classes, activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=outputs)
        
        return model

# %%
build_resnet34 = BuildResNet34()
resnet34_model = build_resnet34.build_model(classes=1000)
# Out:
# 2022-12-30 11:04:30.890522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:30.920367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:30.920451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:30.920804: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-30 11:04:30.921377: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:30.921441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:30.921484: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:31.187148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:31.187251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:31.187304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-30 11:04:31.187360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45877 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
resnet34_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['activation[0][0]']
#  D)                             )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36864       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36864       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 56, 56, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 64)   36864       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 64)   36864       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['activation_2[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 56, 56, 64)   0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 64)   36864       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 64)   36864       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['activation_4[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  73728       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  8192        ['activation_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 128)  147456      ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147456      ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 128)  147456      ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['activation_8[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 128)  147456      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 128)  147456      ['activation_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['activation_10[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 128)  0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 128)  147456      ['activation_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 128)  147456      ['activation_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['activation_12[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 256)  294912      ['activation_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 256)  32768       ['activation_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#  activation_16 (Activation)     (None, 14, 14, 256)  0           ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['activation_16[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_18 (Activation)     (None, 14, 14, 256)  0           ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['activation_18[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_20 (Activation)     (None, 14, 14, 256)  0           ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['activation_20[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 14, 14, 256)  0           ['activation_22[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 256)  0           ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 256)  589824      ['activation_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 14, 14, 256)  0           ['activation_24[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['add_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 512)    1179648     ['activation_26[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 512)    131072      ['activation_26[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 512)    2359296     ['activation_27[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_31[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_28 (Activation)     (None, 7, 7, 512)    0           ['add_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 512)    2359296     ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 512)    2359296     ['activation_29[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_33[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 7, 7, 512)    0           ['activation_28[0][0]',
#                                                                   'batch_normalization_33[0][0]']
#
#  activation_30 (Activation)     (None, 7, 7, 512)    0           ['add_14[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 512)    2359296     ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 512)    2359296     ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 7, 7, 512)    0           ['activation_30[0][0]',
#                                                                   'batch_normalization_35[0][0]']
#
#  activation_32 (Activation)     (None, 7, 7, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_32[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1000)         513000      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,814,696
# Trainable params: 21,797,672
# Non-trainable params: 17,024
# __________________________________________________________________________________________________
