# %% [markdown]
# ## Download Data

# %%
# !pip install tensorflow==2.8.0

# %%
# !pip install -U --no-cache-dir gdown --pre
# !gdown --id 1hIA30U0onXAHyqeic-uuzJ-xbzt8J1EQ

# %%
# !unzip scenes_classification.zip

# %%
import os 
import cv2
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# ## Scenes Classification CONCATENATE Operator

# %%
# list đường dẫn các file ảnh
SCENES_CLASSIFICATION_PATH = 'scenes_classification'
train_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/train/**/*.jpg'))
val_path_imgs = list(glob.glob(SCENES_CLASSIFICATION_PATH+'/val/**/*.jpg'))

# %%
# split đường dẫn các file để lấy label cho ảnh và tao thành dataframe để  thống kê
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1], train_path_imgs))
file_path = pd.Series(train_path_imgs, name='File_Path').astype(str)
labels = pd.Series(labels, name='Labels')
data = pd.concat([file_path, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                            File_Path     Labels
# 0  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...     street
# 1  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...  buildings
# 2  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...     street
# 3  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...    glacier
# 4  /home/aivn48/Desktop/DEL/Week25/2022/scenes_cl...   mountain

# %%
# vẽ các ảnh tương ứng với label
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.File_Path[i]))
    ax.set_title(data.Labels[i])
plt.tight_layout()
plt.show()

# %%
data.Labels.value_counts()
# Out:
# mountain     2512
# glacier      2404
# street       2382
# sea          2274
# forest       2271
# buildings    2191
# Name: Labels, dtype: int64

# %%
# Thống kê số lượng ảnh cho từng label 
counts = data.Labels.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.xticks(rotation=50);

# %%
batch_size = 32
img_height = 112
img_width = 112

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  directory= os.path.join(SCENES_CLASSIFICATION_PATH, 'train'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 14034 files belonging to 6 classes.
# 2022-12-29 15:37:12.259840: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-29 15:37:12.260293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 15:37:12.260395: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 15:37:12.260442: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 15:37:12.546118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 15:37:12.546218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 15:37:12.546272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-29 15:37:12.546331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45932 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  directory=os.path.join(SCENES_CLASSIFICATION_PATH, 'val'),
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3000 files belonging to 6 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
    layers.Rescaling(scale=1./255),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)
                                        , fill_mode='nearest'),
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_augmentation(np.expand_dims(images[0].numpy(),axis=0).astype("uint8"))[0])
    plt.title(class_names[labels[0]])
    plt.axis("off")

# %% [markdown]
# ## DenseNet121 (skip connection: Concat)

# %%
class BuildDensenet121():
    def __init__(self):
        pass
    
    
    def conv_block(self, inputs, k=32):
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=4*k, kernel_size=(1,1), use_bias=False)(x)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=k, kernel_size=(3,3), padding='same', use_bias=False)(x)
        
        skip_connection = layers.Concatenate(axis=-1)([inputs,x])
        
        return skip_connection
    
    
    def dense_block(self, x, nums_block, k=32):
        for i in range(nums_block):
            x = self.conv_block(x, 32)
        return x
        
    
    
    def trasition_layer(self, inputs, fraction=0.5):
        channels = inputs.shape[-1]
        x = layers.BatchNormalization()(inputs)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters=fraction*channels, kernel_size=(1,1), use_bias=False)(x)
        x = layers.AveragePooling2D(2, strides=2)(x)
        
        return x
    
    def build_model(self, classes, input_shape=(224,224,3)):
        inputs = layers.Input(shape=input_shape)
        
        x = layers.ZeroPadding2D(padding=((3, 3)))(inputs)
        x = layers.Conv2D(64, 7, strides=2, use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.ZeroPadding2D(padding=((1, 1)))(x)
        x = layers.MaxPooling2D(3, strides=2)(x)
        
        # 1-6
        x = self.dense_block(x, nums_block=6)
        x = self.trasition_layer(x)
        
        # 2-12
        x = self.dense_block(x, nums_block=12)
        x = self.trasition_layer(x)
        
        # 3-24
        x = self.dense_block(x, nums_block=24)
        x = self.trasition_layer(x)
        
        #4-16
        x = self.dense_block(x, nums_block=16)
        
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.GlobalAveragePooling2D()(x)
        outputs = layers.Dense(classes, activation='softmax')(x)
        
        model = Model(inputs=inputs, outputs=outputs)
        
        return model

# %%
build_densenet121 = BuildDensenet121()
densenet121_model = build_densenet121.build_model(input_shape=(img_height, img_width, 3), classes=6)

image_input = layers.Input(shape=(img_height,img_width,3))
x = data_augmentation(image_input)
x = densenet121_model(x)
scenes_classification_densenet121_model = Model(inputs=image_input, outputs=x)

scenes_classification_densenet121_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 112, 3)]     0
#
#  sequential (Sequential)     (None, 112, 112, 3)       0
#
#  model (Functional)          (None, 6)                 7043654
#
# =================================================================
# Total params: 7,043,654
# Trainable params: 6,960,006
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
num_epochs = 100

scenes_classification_densenet121_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                      loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
                      metrics=['accuracy'])


history = scenes_classification_densenet121_model.fit(train_ds,
                                epochs = num_epochs,
                                validation_data = val_ds)
# Out:
# Epoch 1/100
# 2022-12-29 15:37:18.434382: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-12-29 15:37:19.523549: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 439/439 [==============================] - 29s 52ms/step - loss: 1.0905 - accuracy: 0.5837 - val_loss: 1.5708 - val_accuracy: 0.4260
# Epoch 2/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.9222 - accuracy: 0.6489 - val_loss: 0.9481 - val_accuracy: 0.6480
# Epoch 3/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.8311 - accuracy: 0.6908 - val_loss: 0.9285 - val_accuracy: 0.6567
# Epoch 4/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.7664 - accuracy: 0.7162 - val_loss: 3.1575 - val_accuracy: 0.3260
# Epoch 5/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.7284 - accuracy: 0.7315 - val_loss: 1.6849 - val_accuracy: 0.4873
# Epoch 6/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.6910 - accuracy: 0.7466 - val_loss: 1.7837 - val_accuracy: 0.4250
# Epoch 7/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.6678 - accuracy: 0.7546 - val_loss: 1.0463 - val_accuracy: 0.6023
# Epoch 8/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.6380 - accuracy: 0.7666 - val_loss: 1.1836 - val_accuracy: 0.5800
# Epoch 9/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.6128 - accuracy: 0.7760 - val_loss: 1.4997 - val_accuracy: 0.5457
# Epoch 10/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.5986 - accuracy: 0.7842 - val_loss: 1.0133 - val_accuracy: 0.6280
# Epoch 11/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.5747 - accuracy: 0.7912 - val_loss: 1.1565 - val_accuracy: 0.5797
# Epoch 12/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.5673 - accuracy: 0.7920 - val_loss: 0.9167 - val_accuracy: 0.6570
# Epoch 13/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.5423 - accuracy: 0.8018 - val_loss: 1.2558 - val_accuracy: 0.5753
# Epoch 14/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.5313 - accuracy: 0.8060 - val_loss: 0.6511 - val_accuracy: 0.7587
# Epoch 15/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.5217 - accuracy: 0.8075 - val_loss: 1.1973 - val_accuracy: 0.5827
# Epoch 16/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.5079 - accuracy: 0.8152 - val_loss: 0.8036 - val_accuracy: 0.7267
# Epoch 17/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0
100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.2645 - accuracy: 0.9029 - val_loss: 0.7527 - val_accuracy: 0.7820
# Epoch 48/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.2737 - accuracy: 0.8992 - val_loss: 0.7708 - val_accuracy: 0.7660
# Epoch 49/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.2594 - accuracy: 0.9062 - val_loss: 0.8000 - val_accuracy: 0.7687
# Epoch 50/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.2562 - accuracy: 0.9053 - val_loss: 1.6635 - val_accuracy: 0.6153
# Epoch 51/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.2528 - accuracy: 0.9084 - val_loss: 1.0256 - val_accuracy: 0.7293
# Epoch 52/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.2426 - accuracy: 0.9096 - val_loss: 1.0223 - val_accuracy: 0.7183
# Epoch 53/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.2402 - accuracy: 0.9111 - val_loss: 1.2407 - val_accuracy: 0.6773
# Epoch 54/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.2350 - accuracy: 0.9139 - val_loss: 0.8091 - val_accuracy: 0.7630
# Epoch 55/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.2350 - accuracy: 0.9148 - val_loss: 0.8110 - val_accuracy: 0.7670
# Epoch 56/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.2328 - accuracy: 0.9157 - val_loss: 1.0235 - val_accuracy: 0.6970
# Epoch 57/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.2189 - accuracy: 0.9214 - val_loss: 0.5991 - val_accuracy: 0.8087
# Epoch 58/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.2242 - accuracy: 0.9200 - val_loss: 0.7221 - val_accuracy: 0.7853
# Epoch 59/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.2266 - accuracy: 0.9173 - val_loss: 0.8584 - val_accuracy: 0.7520
# Epoch 60/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.2168 - accuracy: 0.9183 - val_loss: 0.8001 - val_accuracy: 0.7703
# Epoch 61/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.2068 - accuracy: 0.9237 - val_loss: 0.7139 - val_accuracy: 0.7907
# Epoch 62/100
# 439/439 [==============================] - 21s 47ms/step - loss: 0.2183 - accuracy: 0.9204 - val_loss: 0.7533 - val_accuracy: 0.7743
# Epoch 63/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.2075 - accuracy: 0.9231 - val_loss: 0.9197 - val_accuracy: 0.7423
# Epoch 64/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.1988 - accuracy: 0.9297 - val_loss: 1.2065 - val_accuracy: 0.6907
# Epoch 65/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.1961 - accuracy: 0.9258 - val_loss: 1.3665 - val_accuracy: 0.6647
# Epoch 66/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.2017 - accuracy: 0.9267 - val_loss: 0.9266 - val_accuracy: 0.7307
# Epoch 67/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.1909 - accuracy: 0.9300 - val_loss: 0.8029 - val_accuracy: 0.7707
# Epoch 68/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1973 - accuracy: 0.9273 - val_loss: 1.1276 - val_accuracy: 0.7220
# Epoch 69/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1909 - accuracy: 0.9301 - val_loss: 0.6103 - val_accuracy: 0.8280
# Epoch 70/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.1899 - accuracy: 0.9288 - val_loss: 0.8211 - val_accuracy: 0.7677
# Epoch 71/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.1719 - accuracy: 0.9387 - val_loss: 0.6411 - val_accuracy: 0.8107
# Epoch 72/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.1854 - accuracy: 0.9343 - val_loss: 0.8163 - val_accuracy: 0.7857
# Epoch 73/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.1803 - accuracy: 0.9358 - val_loss: 1.2916 - val_accuracy: 0.7003
# Epoch 74/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1741 - accuracy: 0.9381 - val_loss: 0.7322 - val_accuracy: 0.8053
# Epoch 75/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1682 - accuracy: 0.9389 - val_loss: 0.8420 - val_accuracy: 0.7770
# Epoch 76/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1696 - accuracy: 0.9348 - val_loss: 1.1719 - val_accuracy: 0.7210
# Epoch 77/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1606 - accuracy: 0.9398 - val_loss: 0.6868 - val_accuracy: 0.8113
# Epoch 78/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.1653 - accuracy: 0.9403 - val_loss: 1.1865 - val_accuracy: 0.7003
# Epoch 79/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1621 - accuracy: 0.9409 - val_loss: 0.8903 - val_accuracy: 0.7763
# Epoch 80/100
# 439/439 [==============================] - 21s 49ms/step - loss: 0.1628 - accuracy: 0.9378 - val_loss: 1.0977 - val_accuracy: 0.7223
# Epoch 81/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1526 - accuracy: 0.9456 - val_loss: 0.7127 - val_accuracy: 0.8090
# Epoch 82/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1643 - accuracy: 0.9387 - val_loss: 1.0465 - val_accuracy: 0.7393
# Epoch 83/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1614 - accuracy: 0.9401 - val_loss: 0.8892 - val_accuracy: 0.7747
# Epoch 84/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1496 - accuracy: 0.9456 - val_loss: 0.8552 - val_accuracy: 0.7887
# Epoch 85/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1562 - accuracy: 0.9428 - val_loss: 1.6128 - val_accuracy: 0.6637
# Epoch 86/100
# 439/439 [==============================] - 22s 51ms/step - loss: 0.1500 - accuracy: 0.9430 - val_loss: 1.0179 - val_accuracy: 0.7547
# Epoch 87/100
# 439/439 [==============================] - 22s 49ms/step - loss: 0.1392 - accuracy: 0.9520 - val_loss: 1.3583 - val_accuracy: 0.6580
# Epoch 88/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1424 - accuracy: 0.9486 - val_loss: 1.9624 - val_accuracy: 0.6117
# Epoch 89/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1390 - accuracy: 0.9477 - val_loss: 1.1703 - val_accuracy: 0.7477
# Epoch 90/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1393 - accuracy: 0.9493 - val_loss: 0.9394 - val_accuracy: 0.7747
# Epoch 91/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1364 - accuracy: 0.9488 - val_loss: 0.7826 - val_accuracy: 0.8003
# Epoch 92/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1428 - accuracy: 0.9476 - val_loss: 0.8913 - val_accuracy: 0.7697
# Epoch 93/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1319 - accuracy: 0.9502 - val_loss: 0.7307 - val_accuracy: 0.8150
# Epoch 94/100
# 439/439 [==============================] - 21s 48ms/step - loss: 0.1382 - accuracy: 0.9505 - val_loss: 1.0220 - val_accuracy: 0.7583
# Epoch 95/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1403 - accuracy: 0.9476 - val_loss: 0.7486 - val_accuracy: 0.8123
# Epoch 96/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1330 - accuracy: 0.9503 - val_loss: 0.9423 - val_accuracy: 0.7680
# Epoch 97/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1276 - accuracy: 0.9550 - val_loss: 0.7693 - val_accuracy: 0.8130
# Epoch 98/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1379 - accuracy: 0.9493 - val_loss: 0.9818 - val_accuracy: 0.7583
# Epoch 99/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1200 - accuracy: 0.9564 - val_loss: 1.4733 - val_accuracy: 0.7043
# Epoch 100/100
# 439/439 [==============================] - 22s 50ms/step - loss: 0.1241 - accuracy: 0.9559 - val_loss: 0.9244 - val_accuracy: 0.7550

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error scenes_classification_densenet121_model')
plt.legend()
plt.grid(True)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy scenes_classification_densenet121_model')
plt.legend()
plt.grid(True)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy  epoch
# 95  0.132986  0.950264  0.942286      0.768000     95
# 96  0.127650  0.954966  0.769258      0.813000     96
# 97  0.137934  0.949266  0.981762      0.758333     97
# 98  0.120016  0.956392  1.473279      0.704333     98
# 99  0.124082  0.955893  0.924409      0.755000     99
